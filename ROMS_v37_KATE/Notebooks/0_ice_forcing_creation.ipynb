# %%
import xarray as xr

# %%
def save_to_netcdf(ds, name):
    ds.to_netcdf(path=f'../Case_upw_ice/{name}.nc', format='NETCDF4')

# %%
arome_ds = xr.open_dataset('../Case_upw_ice/arome_2017_onestep.nc')
his_ds = xr.open_dataset('../Case_upw_ice/ocean_his.nc')

# %%
arome_ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 2, y: 929, x: 719)
# Coordinates:
#     lat      (y, x) float64 ...
#     lon      (y, x) float64 ...
#   * time     (time) datetime64[ns] 2017-01-01 2017-01-01T03:00:00
# Dimensions without coordinates: y, x
# Data variables:
#     Pair     (time, y, x) float32 ...
#     Qair     (time, y, x) float32 ...
#     Tair     (time, y, x) float32 ...
#     Uwind    (time, y, x) float32 ...
#     Vwind    (time, y, x) float32 ...
#     cloud    (time, y, x) float32 ...
#     rain     (time, y, x) float32 ...
# Attributes:
#     comment:      Re-arranged for ROMS forcing by arome2roms.m
#     Conventions:  CF-1.0
#     institution:  Norwegian Meteorological Institute, met.no
#     source:       AROME-MetCoOp (SURFEX output)
#     history:      Wed Sep 21 11:22:23 2022: ncks -d time,1,2 arome_metcoop_de...
#     NCO:          4.7.2
